# %% [markdown]
# <a href="https://colab.research.google.com/github/ZarinSaima333/ZarinSaima333-Statistic-for-Data-Science/blob/main/Copy_of_Stats_Practicals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statistics

# %%
#mean, meadian, mode
df=sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# @title total_bill

from matplotlib import pyplot as plt
df['total_bill'].plot(kind='hist', bins=20, title='total_bill')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
np.mean(df["total_bill"])
# Out:
# 19.78594262295082

# %%
np.median(df["total_bill"])
# Out:
# 17.795

# %%
np.mode(df["total_bill"]) #numpy does not have a mode func
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-32797e74a3ef> in <cell line: 1>()
# ----> 1 np.mode(df["total_bill"]) #numpy does not have a mode func
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     326             raise RuntimeError("Tester was removed in NumPy 1.25.")
#     327
# --> 328         raise AttributeError("module {!r} has no attribute "
#     329                              "{!r}".format(__name__, attr))
#     330
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
statistics.mode(df["total_bill"])
# Out:
# 13.42

# %%
np.percentile(df1["sepal_length"],[25,75])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-20def0651c5a> in <cell line: 1>()
# ----> 1 np.percentile(df1["sepal_length"],[25,75])
#
# NameError: name 'df1' is not defined

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(df["total_bill"],kde=True)#with pdf
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df1=sns.load_dataset("iris")

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(df1["sepal_width"],kde=True)#with pdf
#gaussian distribuition 68.8,95,99.7
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.countplot(df1["species"]) #bar graph

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Define our dataset
dataset= [11,10,12,14,12,15,14,13,15,102,12,14,17,19,107, 10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]

# %%
plt.hist(dataset)
# Out:
# (array([31.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  3.]),
#  array([ 10. ,  19.8,  29.6,  39.4,  49.2,  59. ,  68.8,  78.6,  88.4,
#          98.2, 108. ]),
#  <BarContainer object of 10 artists>)

# %%
## Z Score
outliers=[]

def detect_outliers(data):
  threshold=3 ## 3 std deviation
  mean=np.mean(data)
  std=np.std(data)

  for i in data:
    z_score=(i-mean)/std
    if np.abs(z_score)> threshold:
      outliers.append(i)

  return outliers

# %%
detect_outliers(dataset)
# Out:
# [102, 107, 108]

# %% [markdown]
# #IQR
# 1. Sort the data
# 2. Calculate Q1 aqnd Q3
# 3. IQR(Q3-Q1)
# 4. Find the Lower fence(q1-1.5(iqr))
# 5. Find the upper fence(q3+1.5(iqr))

# %%
dataset=sorted(dataset)
dataset
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  17,
#  19,
#  102,
#  107,
#  108]

# %%
q1,q3=np.percentile(dataset,[25,75])

# %%
print(q1,q3)
# Out:
# 12.0 15.0

# %%
iqr=q3-q1
print(iqr)
# Out:
# 3.0

# %%
## Find the lower fence and higher fence
lower_fence=q1-(1.5*iqr)
higher_fence=q3+(1.5* iqr)

# %%
print(lower_fence,higher_fence)

# %%
import seaborn as sns

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %% [markdown]
# DAY 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from statsmodels.stats.weightstats import ztest as ztest
#H_0= mean =100
data=[88,92,94,94,96,97,97,97,999,999,105,109,109,109,110,112,112,113,114,115]
ztest(data,value=100)

#if p-value=0.1>0.05=sig we reject the null hypothesis
# 0.13128606283486277 this value is helping to compare with the  p value

#p_value<significant value: we accept the H_0
# Out:
# (1.5090497763982864, 0.13128606283486277)

# %% [markdown]
# ​​so if mean iq before meditation is 110 and p-value is 0.002 it means that even after taking medication the iq will be around 110 it means medication has no effect
#
# ```
# # This is formatted as code
# ```

# %%
#T test
ages=[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
ages_mean=np.mean(ages)
ages_mean
# Out:
# 30.34375

# %%
sample_size=10
age_sample=np.random.choice(ages,sample_size)

# %%
age_sample
# Out:
# array([43, 30, 20, 70, 21, 18, 28, 43, 16, 55])

# %%
ages_sample_mean=np.mean(age_sample)
ages_sample_mean
# Out:
# 34.4

# %%
from scipy.stats import ttest_1samp

ttest_1samp(age_sample,30)
# Out:
# TtestResult(statistic=0.7758801774444578, pvalue=0.4577226612263263, df=9)

# %%
ttest_1samp(age_sample,31)
# Out:
# TtestResult(statistic=0.5995437734798083, pvalue=0.563597128948106, df=9)

# %%
ttest_1samp(age_sample,26)
# Out:
# TtestResult(statistic=1.481225793303056, pvalue=0.17268508962953905, df=9)

# %%
#ci er vitor naki checking

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#rejected

# %% [markdown]
# ![image.png](data:image/png;base64,...)
